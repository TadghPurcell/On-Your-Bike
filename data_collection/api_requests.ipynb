# %%
import requests
import json
from pprint import pprint

# Get the API key for Dublin bikes
f = open("./dbinfo.json")
BIKE_API_KEY = json.load(f)['JCKey']
f.close()

#Get the API key for Open weather
f = open("./dbinfo.json")
WEATHER_API_KEY = json.load(f)['weatherKey']
f.close()

# URI and name
STATIONS_URI = 'https://api.jcdecaux.com/vls/v1/stations'
NAME = 'dublin'
#Weather URI 
WEATHER_URI = 'https://api.openweathermap.org/data/2.5/weather'

# %%
# Make an API request
r = requests.get(STATIONS_URI, params={'apiKey':BIKE_API_KEY, 'contract':NAME})
json.loads(r.text)
# Out:
# [{'number': 42,
#   'contract_name': 'dublin',
#   'name': 'SMITHFIELD NORTH',
#   'address': 'Smithfield North',
#   'position': {'lat': 53.349562, 'lng': -6.278198},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 8,
#   'available_bikes': 22,
#   'status': 'OPEN',
#   'last_update': 1707820096000},
#  {'number': 30,
#   'contract_name': 'dublin',
#   'name': 'PARNELL SQUARE NORTH',
#   'address': 'Parnell Square North',
#   'position': {'lat': 53.3537415547453, 'lng': -6.26530144781526},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820561000},
#  {'number': 54,
#   'contract_name': 'dublin',
#   'name': 'CLONMEL STREET',
#   'address': 'Clonmel Street',
#   'position': {'lat': 53.336021, 'lng': -6.26298},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 33,
#   'available_bike_stands': 12,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1707820431000},
#  {'number': 108,
#   'contract_name': 'dublin',
#   'name': 'AVONDALE ROAD',
#   'address': 'Avondale Road',
#   'position': {'lat': 53.359405, 'lng': -6.276142},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 35,
#   'available_bike_stands': 35,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820303000},
#  {'number': 20,
#   'contract_name': 'dublin',
#   'name': 'JAMES STREET EAST',
#   'address': 'James Street East',
#   'position': {'lat': 53.336597, 'lng': -6.248109},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 7,
#   'available_bikes': 23,
#   'status': 'OPEN',
#   'last_update': 1707820443000},
#  {'number': 56,
#   'contract_name': 'dublin',
#   'name': 'MOUNT STREET LOWER',
#   'address': 'Mount Street Lower',
#   'position': {'lat': 53.33796, 'lng': -6.24153},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 11,
#   'available_bikes': 28,
#   'status': 'OPEN',
#   'last_update': 1707820480000},
#  {'number': 6,
#   'contract_name': 'dublin',
#   'name': 'CHRISTCHURCH PLACE',
#   'address': 'Christchurch Place',
#   'position': {'lat': 53.343368, 'lng': -6.27012},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1707820651000},
#  {'number': 18,
#   'contract_name': 'dublin',
#   'name': 'GRANTHAM STREET',
#   'address': 'Grantham Street',
#   'position': {'lat': 53.334123, 'lng': -6.265436},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 26,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820326000},
#  {'number': 32,
#   'contract_name': 'dublin',
#   'name': 'PEARSE STREET',
#   'address': 'Pearse Street',
#   'position': {'lat': 53.344304, 'lng': -6.250427},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 10,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820579000},
#  {'number': 52,
#   'contract_name': 'dublin',
#   'name': 'YORK STREET EAST',
#   'address': 'York Street East',
#   'position': {'lat': 53.338755, 'lng': -6.262003},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 32,
#   'available_bike_stands': 8,
#   'available_bikes': 24,
#   'status': 'OPEN',
#   'last_update': 1707820377000},
#  {'number': 48,
#   'contract_name': 'dublin',
#   'name': 'EXCISE WALK',
#   'address': 'Excise Walk',
#   'position': {'lat': 53.347777, 'lng': -6.244239},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 33,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1707820533000},
#  {'number': 13,
#   'contract_name': 'dublin',
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'address': 'Fitzwilliam Square West',
#   'position': {'lat': 53.336074, 'lng': -6.252825},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 5,
#   'available_bikes': 24,
#   'status': 'OPEN',
#   'last_update': 1707820309000},
#  {'number': 43,
#   'contract_name': 'dublin',
#   'name': 'PORTOBELLO ROAD',
#   'address': 'Portobello Road',
#   'position': {'lat': 53.330091, 'lng': -6.268044},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 24,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1707820077000},
#  {'number': 31,
#   'contract_name': 'dublin',
#   'name': 'PARNELL STREET',
#   'address': 'Parnell Street',
#   'position': {'lat': 53.350929, 'lng': -6.265125},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 11,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1707820191000},
#  {'number': 98,
#   'contract_name': 'dublin',
#   'name': 'FREDERICK STREET SOUTH',
#   'address': 'Frederick Street South',
#   'position': {'lat': 53.341515, 'lng': -6.256853},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 4,
#   'available_bikes': 35,
#   'status': 'OPEN',
#   'last_update': 1707820301000},
#  {'number': 14,
#   'contract_name': 'dublin',
#   'name': 'FOWNES STREET UPPER',
#   'address': 'Fownes Street Upper',
#   'position': {'lat': 53.344603, 'lng': -6.263371},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 9,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1707820372000},
#  {'number': 1,
#   'contract_name': 'dublin',
#   'name': 'CLARENDON ROW',
#   'address': 'Clarendon Row',
#   'position': {'lat': 53.340927, 'lng': -6.262501},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 31,
#   'available_bike_stands': 0,
#   'available_bikes': 31,
#   'status': 'OPEN',
#   'last_update': 1707820063000},
#  {'number': 23,
#   'contract_name': 'dublin',
#   'name': 'CUSTOM HOUSE',
#   'address': 'Custom House',
#   'position': {'lat': 53.348279, 'lng': -6.254662},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 15,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1707820346000},
#  {'number': 106,
#   'contract_name': 'dublin',
#   'name': 'RATHDOWN ROAD',
#   'address': 'Rathdown Road',
#   'position': {'lat': 53.35893, 'lng': -6.280337},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 34,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1707820065000},
#  {'number': 112,
#   'contract_name': 'dublin',
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'address': "North Circular Road (O'Connell's)",
#   'position': {'lat': 53.357841, 'lng': -6.251557},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820272000},
#  {'number': 68,
#   'contract_name': 'dublin',
#   'name': 'HANOVER QUAY',
#   'address': 'Hanover Quay',
#   'position': {'lat': 53.344115, 'lng': -6.237153},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 11,
#   'available_bikes': 27,
#   'status': 'OPEN',
#   'last_update': 1707820389000},
#  {'number': 74,
#   'contract_name': 'dublin',
#   'name': 'OLIVER BOND STREET',
#   'address': 'Oliver Bond Street',
#   'position': {'lat': 53.343893, 'lng': -6.280531},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 27,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820385000},
#  {'number': 87,
#   'contract_name': 'dublin',
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'address': 'Collins Barracks Museum',
#   'position': {'lat': 53.347477, 'lng': -6.28525},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 38,
#   'available_bike_stands': 38,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820061000},
#  {'number': 84,
#   'contract_name': 'dublin',
#   'name': 'BROOKFIELD ROAD',
#   'address': 'Brookfield Road',
#   'position': {'lat': 53.339005, 'lng': -6.300217},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820459000},
#  {'number': 90,
#   'contract_name': 'dublin',
#   'name': 'BENSON STREET',
#   'address': 'Benson Street',
#   'position': {'lat': 53.344153, 'lng': -6.233451},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 5,
#   'available_bikes': 35,
#   'status': 'OPEN',
#   'last_update': 1707820503000},
#  {'number': 11,
#   'contract_name': 'dublin',
#   'name': 'EARLSFORT TERRACE',
#   'address': 'Earlsfort Terrace',
#   'position': {'lat': 53.334295, 'lng': -6.258503},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 4,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1707820590000},
#  {'number': 17,
#   'contract_name': 'dublin',
#   'name': 'GOLDEN LANE',
#   'address': 'Golden Lane',
#   'position': {'lat': 53.340803, 'lng': -6.267732},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 10,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1707820233000},
#  {'number': 45,
#   'contract_name': 'dublin',
#   'name': 'DEVERELL PLACE',
#   'address': 'Deverell Place',
#   'position': {'lat': 53.351464, 'lng': -6.255265},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 21,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1707820049000},
#  {'number': 114,
#   'contract_name': 'dublin',
#   'name': 'WILTON TERRACE (PARK)',
#   'address': 'Wilton Terrace (Park)',
#   'position': {'lat': 53.333653, 'lng': -6.248345},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 19,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1707820360000},
#  {'number': 72,
#   'contract_name': 'dublin',
#   'name': 'JOHN STREET WEST',
#   'address': 'John Street West',
#   'position': {'lat': 53.343105, 'lng': -6.277167},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 31,
#   'available_bike_stands': 21,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1707820402000},
#  {'number': 63,
#   'contract_name': 'dublin',
#   'name': 'FENIAN STREET',
#   'address': 'Fenian Street',
#   'position': {'lat': 53.341428, 'lng': -6.24672},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 35,
#   'available_bike_stands': 14,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820629000},
#  {'number': 113,
#   'contract_name': 'dublin',
#   'name': 'MERRION SQUARE SOUTH',
#   'address': 'Merrion Square South',
#   'position': {'lat': 53.338614, 'lng': -6.248606},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 29,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1707820360000},
#  {'number': 91,
#   'contract_name': 'dublin',
#   'name': 'SOUTH DOCK ROAD',
#   'address': 'South Dock Road',
#   'position': {'lat': 53.341833, 'lng': -6.231291},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 9,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1707820216000},
#  {'number': 99,
#   'contract_name': 'dublin',
#   'name': 'CITY QUAY',
#   'address': 'City Quay',
#   'position': {'lat': 53.346637, 'lng': -6.246154},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 14,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1707820379000},
#  {'number': 9,
#   'contract_name': 'dublin',
#   'name': 'EXCHEQUER STREET',
#   'address': 'Exchequer Street',
#   'position': {'lat': 53.343034, 'lng': -6.263578},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 1,
#   'available_bikes': 23,
#   'status': 'OPEN',
#   'last_update': 1707820291000},
#  {'number': 67,
#   'contract_name': 'dublin',
#   'name': 'THE POINT',
#   'address': 'The Point',
#   'position': {'lat': 53.346867, 'lng': -6.230852},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820629000},
#  {'number': 116,
#   'contract_name': 'dublin',
#   'name': 'BROADSTONE',
#   'address': 'Broadstone',
#   'position': {'lat': 53.3547, 'lng': -6.272314},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820180000},
#  {'number': 55,
#   'contract_name': 'dublin',
#   'name': 'HATCH STREET',
#   'address': 'Hatch Street',
#   'position': {'lat': 53.33403, 'lng': -6.260714},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 36,
#   'available_bike_stands': 25,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1707820440000},
#  {'number': 62,
#   'contract_name': 'dublin',
#   'name': 'LIME STREET',
#   'address': 'Lime Street',
#   'position': {'lat': 53.346026, 'lng': -6.243576},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 11,
#   'available_bikes': 29,
#   'status': 'OPEN',
#   'last_update': 1707820308000},
#  {'number': 5,
#   'contract_name': 'dublin',
#   'name': 'CHARLEMONT PLACE',
#   'address': 'Charlemont Street',
#   'position': {'lat': 53.330662, 'lng': -6.260177},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820626000},
#  {'number': 97,
#   'contract_name': 'dublin',
#   'name': 'KILMAINHAM GAOL',
#   'address': 'Kilmainham Gaol',
#   'position': {'lat': 53.342113, 'lng': -6.310015},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820139000},
#  {'number': 61,
#   'contract_name': 'dublin',
#   'name': 'HARDWICKE PLACE',
#   'address': 'Hardwicke Place',
#   'position': {'lat': 53.357043, 'lng': -6.263232},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 21,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1707820074000},
#  {'number': 77,
#   'contract_name': 'dublin',
#   'name': 'WOLFE TONE STREET',
#   'address': 'Wolfe Tone Street',
#   'position': {'lat': 53.348875, 'lng': -6.267459},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 22,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820650000},
#  {'number': 73,
#   'contract_name': 'dublin',
#   'name': 'FRANCIS STREET',
#   'address': 'Francis Street',
#   'position': {'lat': 53.342081, 'lng': -6.275233},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820486000},
#  {'number': 4,
#   'contract_name': 'dublin',
#   'name': 'GREEK STREET',
#   'address': 'Greek Street',
#   'position': {'lat': 53.346874, 'lng': -6.272976},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 0,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820078000},
#  {'number': 49,
#   'contract_name': 'dublin',
#   'name': 'GUILD STREET',
#   'address': 'Guild Street',
#   'position': {'lat': 53.347932, 'lng': -6.240928},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 21,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1707820403000},
#  {'number': 19,
#   'contract_name': 'dublin',
#   'name': 'HERBERT PLACE',
#   'address': 'Herbert Place',
#   'position': {'lat': 53.334432, 'lng': -6.245575},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 2,
#   'available_bikes': 28,
#   'status': 'OPEN',
#   'last_update': 1707820312000},
#  {'number': 7,
#   'contract_name': 'dublin',
#   'name': 'HIGH STREET',
#   'address': 'High Street',
#   'position': {'lat': 53.343565, 'lng': -6.275071},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 22,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820243000},
#  {'number': 60,
#   'contract_name': 'dublin',
#   'name': 'NORTH CIRCULAR ROAD',
#   'address': 'North Circular Road',
#   'position': {'lat': 53.359624, 'lng': -6.260348},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820434000},
#  {'number': 102,
#   'contract_name': 'dublin',
#   'name': 'WESTERN WAY',
#   'address': 'Western Way',
#   'position': {'lat': 53.354929, 'lng': -6.269425},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820241000},
#  {'number': 38,
#   'contract_name': 'dublin',
#   'name': 'TALBOT STREET',
#   'address': 'Talbot Street',
#   'position': {'lat': 53.350974, 'lng': -6.25294},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 18,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820324000},
#  {'number': 53,
#   'contract_name': 'dublin',
#   'name': 'NEWMAN HOUSE',
#   'address': 'Newman House',
#   'position': {'lat': 53.337132, 'lng': -6.26059},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 22,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1707820290000},
#  {'number': 58,
#   'contract_name': 'dublin',
#   'name': "SIR PATRICK DUN'S",
#   'address': "Sir Patrick's Dun",
#   'position': {'lat': 53.339218, 'lng': -6.240642},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 0,
#   'available_bikes': 39,
#   'status': 'OPEN',
#   'last_update': 1707820624000},
#  {'number': 66,
#   'contract_name': 'dublin',
#   'name': 'NEW CENTRAL BANK',
#   'address': 'New Central Bank',
#   'position': {'lat': 53.347122, 'lng': -6.234749},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 5,
#   'available_bikes': 33,
#   'status': 'OPEN',
#   'last_update': 1707820502000},
#  {'number': 104,
#   'contract_name': 'dublin',
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'address': 'Grangegorman Lower (Central)',
#   'position': {'lat': 53.355173, 'lng': -6.278424},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 35,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1707820337000},
#  {'number': 101,
#   'contract_name': 'dublin',
#   'name': 'KING STREET NORTH',
#   'address': 'King Street North',
#   'position': {'lat': 53.350291, 'lng': -6.273507},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 27,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820242000},
#  {'number': 115,
#   'contract_name': 'dublin',
#   'name': 'KILLARNEY STREET',
#   'address': 'Killarney Street',
#   'position': {'lat': 53.354845, 'lng': -6.247579},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 25,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1707820434000},
#  {'number': 47,
#   'contract_name': 'dublin',
#   'name': 'HERBERT STREET',
#   'address': 'Herbert Street',
#   'position': {'lat': 53.335742, 'lng': -6.24551},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 24,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1707820142000},
#  {'number': 117,
#   'contract_name': 'dublin',
#   'name': 'HANOVER QUAY EAST',
#   'address': 'Hanover Quay East',
#   'position': {'lat': 53.343653, 'lng': -6.231755},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 0,
#   'available_bikes': 40,
#   'status': 'OPEN',
#   'last_update': 1707820592000},
#  {'number': 8,
#   'contract_name': 'dublin',
#   'name': 'CUSTOM HOUSE QUAY',
#   'address': 'Custom House Quay',
#   'position': {'lat': 53.347884, 'lng': -6.248048},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 27,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820366000},
#  {'number': 27,
#   'contract_name': 'dublin',
#   'name': 'MOLESWORTH STREET',
#   'address': 'Molesworth Street',
#   'position': {'lat': 53.341288, 'lng': -6.258117},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 3,
#   'available_bikes': 17,
#   'status': 'OPEN',
#   'last_update': 1707820517000},
#  {'number': 16,
#   'contract_name': 'dublin',
#   'name': 'GEORGES QUAY',
#   'address': 'Georges Quay',
#   'position': {'lat': 53.347508, 'lng': -6.252192},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 10,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1707820172000},
#  {'number': 96,
#   'contract_name': 'dublin',
#   'name': 'KILMAINHAM LANE',
#   'address': 'Kilmainham Lane',
#   'position': {'lat': 53.341805, 'lng': -6.305085},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820146000},
#  {'number': 82,
#   'contract_name': 'dublin',
#   'name': 'MOUNT BROWN',
#   'address': 'Mount Brown',
#   'position': {'lat': 53.341645, 'lng': -6.29719},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 13,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1707820642000},
#  {'number': 76,
#   'contract_name': 'dublin',
#   'name': 'MARKET STREET SOUTH',
#   'address': 'Market Street South',
#   'position': {'lat': 53.342296, 'lng': -6.287661},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 38,
#   'available_bike_stands': 32,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1707820641000},
#  {'number': 71,
#   'contract_name': 'dublin',
#   'name': 'KEVIN STREET',
#   'address': 'Kevin Street',
#   'position': {'lat': 53.337757, 'lng': -6.267699},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820143000},
#  {'number': 79,
#   'contract_name': 'dublin',
#   'name': 'ECCLES STREET EAST',
#   'address': 'Eccles Street East',
#   'position': {'lat': 53.358115, 'lng': -6.265601},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 27,
#   'available_bike_stands': 23,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820359000},
#  {'number': 69,
#   'contract_name': 'dublin',
#   'name': 'GRAND CANAL DOCK',
#   'address': 'Grand Canal Dock',
#   'position': {'lat': 53.342638, 'lng': -6.238695},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 9,
#   'available_bikes': 29,
#   'status': 'OPEN',
#   'last_update': 1707820605000},
#  {'number': 25,
#   'contract_name': 'dublin',
#   'name': 'MERRION SQUARE EAST',
#   'address': 'Merrion Square East',
#   'position': {'lat': 53.339434, 'lng': -6.246548},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 8,
#   'available_bikes': 22,
#   'status': 'OPEN',
#   'last_update': 1707820406000},
#  {'number': 51,
#   'contract_name': 'dublin',
#   'name': 'YORK STREET WEST',
#   'address': 'York Street West',
#   'position': {'lat': 53.339334, 'lng': -6.264699},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 20,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820050000},
#  {'number': 37,
#   'contract_name': 'dublin',
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'address': "St. Stephen's Green South",
#   'position': {'lat': 53.337494, 'lng': -6.26199},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820640000},
#  {'number': 59,
#   'contract_name': 'dublin',
#   'name': 'DENMARK STREET GREAT',
#   'address': 'Denmark Street Great',
#   'position': {'lat': 53.35561, 'lng': -6.261397},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820648000},
#  {'number': 95,
#   'contract_name': 'dublin',
#   'name': 'ROYAL HOSPITAL',
#   'address': 'Royal Hospital',
#   'position': {'lat': 53.343897, 'lng': -6.29706},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820641000},
#  {'number': 94,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'address': 'Heuston Station (Car Park)',
#   'position': {'lat': 53.346985, 'lng': -6.297804},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820105000},
#  {'number': 105,
#   'contract_name': 'dublin',
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'address': 'Grangegorman Lower (North)',
#   'position': {'lat': 53.355954, 'lng': -6.278378},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 36,
#   'available_bike_stands': 16,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820432000},
#  {'number': 36,
#   'contract_name': 'dublin',
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'address': "St. Stephen's Green East",
#   'position': {'lat': 53.337824, 'lng': -6.256035},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 0,
#   'available_bikes': 40,
#   'status': 'OPEN',
#   'last_update': 1707820517000},
#  {'number': 93,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'address': 'Heuston Station (Central)',
#   'position': {'lat': 53.346603, 'lng': -6.296924},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820053000},
#  {'number': 22,
#   'contract_name': 'dublin',
#   'name': 'TOWNSEND STREET',
#   'address': 'Townsend Street',
#   'position': {'lat': 53.345922, 'lng': -6.254614},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 7,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1707820578000},
#  {'number': 50,
#   'contract_name': 'dublin',
#   'name': 'GEORGES LANE',
#   'address': "George's Lane",
#   'position': {'lat': 53.35023, 'lng': -6.279696},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 25,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1707820532000},
#  {'number': 110,
#   'contract_name': 'dublin',
#   'name': 'PHIBSBOROUGH ROAD',
#   'address': 'Phibsborough Road',
#   'position': {'lat': 53.356307, 'lng': -6.273717},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 28,
#   'available_bikes': 12,
#   'status': 'OPEN',
#   'last_update': 1707820088000},
#  {'number': 12,
#   'contract_name': 'dublin',
#   'name': 'ECCLES STREET',
#   'address': 'Eccles Street',
#   'position': {'lat': 53.359246, 'lng': -6.269779},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820228000},
#  {'number': 34,
#   'contract_name': 'dublin',
#   'name': 'PORTOBELLO HARBOUR',
#   'address': 'Portobello Harbour',
#   'position': {'lat': 53.330362, 'lng': -6.265163},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820546000},
#  {'number': 78,
#   'contract_name': 'dublin',
#   'name': 'MATER HOSPITAL',
#   'address': 'Mater Hospital',
#   'position': {'lat': 53.359967, 'lng': -6.264828},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820083000},
#  {'number': 2,
#   'contract_name': 'dublin',
#   'name': 'BLESSINGTON STREET',
#   'address': 'Blessington Street',
#   'position': {'lat': 53.356769, 'lng': -6.26814},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820089000},
#  {'number': 75,
#   'contract_name': 'dublin',
#   'name': 'JAMES STREET',
#   'address': 'James Street',
#   'position': {'lat': 53.343456, 'lng': -6.287409},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 25,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1707820134000},
#  {'number': 111,
#   'contract_name': 'dublin',
#   'name': 'MOUNTJOY SQUARE EAST',
#   'address': 'Mountjoy Square East',
#   'position': {'lat': 53.356717, 'lng': -6.256359},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820179000},
#  {'number': 26,
#   'contract_name': 'dublin',
#   'name': 'MERRION SQUARE WEST',
#   'address': 'Merrion Square West',
#   'position': {'lat': 53.339764, 'lng': -6.251988},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 11,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1707820145000},
#  {'number': 65,
#   'contract_name': 'dublin',
#   'name': 'CONVENTION CENTRE',
#   'address': 'Convention Centre',
#   'position': {'lat': 53.34744, 'lng': -6.238523},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 18,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1707820459000},
#  {'number': 15,
#   'contract_name': 'dublin',
#   'name': 'HARDWICKE STREET',
#   'address': 'Hardwicke Street',
#   'position': {'lat': 53.355473, 'lng': -6.264423},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820549000},
#  {'number': 86,
#   'contract_name': 'dublin',
#   'name': 'PARKGATE STREET',
#   'address': 'Parkgate Street',
#   'position': {'lat': 53.347972, 'lng': -6.291804},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 38,
#   'available_bike_stands': 38,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820119000},
#  {'number': 35,
#   'contract_name': 'dublin',
#   'name': 'SMITHFIELD',
#   'address': 'Smithfield',
#   'position': {'lat': 53.347692, 'lng': -6.278214},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 24,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1707820580000},
#  {'number': 10,
#   'contract_name': 'dublin',
#   'name': 'DAME STREET',
#   'address': 'Dame Street',
#   'position': {'lat': 53.344007, 'lng': -6.266802},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 0,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1707820407000},
#  {'number': 100,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'address': 'Heuston Bridge (South)',
#   'position': {'lat': 53.347106, 'lng': -6.292041},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 25,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820126000},
#  {'number': 24,
#   'contract_name': 'dublin',
#   'name': 'CATHAL BRUGHA STREET',
#   'address': 'Cathal Brugha Street',
#   'position': {'lat': 53.352149, 'lng': -6.260533},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820389000},
#  {'number': 64,
#   'contract_name': 'dublin',
#   'name': 'SANDWITH STREET',
#   'address': 'Sandwith Street',
#   'position': {'lat': 53.345203, 'lng': -6.247163},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820234000},
#  {'number': 109,
#   'contract_name': 'dublin',
#   'name': 'BUCKINGHAM STREET LOWER',
#   'address': 'Buckingham Street Lower',
#   'position': {'lat': 53.353331, 'lng': -6.249319},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 16,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1707820064000},
#  {'number': 85,
#   'contract_name': 'dublin',
#   'name': 'ROTHE ABBEY',
#   'address': 'Rothe Abbey',
#   'position': {'lat': 53.338776, 'lng': -6.30395},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 35,
#   'available_bike_stands': 27,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1707820071000},
#  {'number': 107,
#   'contract_name': 'dublin',
#   'name': 'CHARLEVILLE ROAD',
#   'address': 'Charleville Road',
#   'position': {'lat': 53.359157, 'lng': -6.281866},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1707820394000},
#  {'number': 33,
#   'contract_name': 'dublin',
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'address': "Princes Street / O'Connell Street",
#   'position': {'lat': 53.349013, 'lng': -6.260311},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 15,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1707820627000},
#  {'number': 44,
#   'contract_name': 'dublin',
#   'name': 'UPPER SHERRARD STREET',
#   'address': 'Upper Sherrard Street',
#   'position': {'lat': 53.358437, 'lng': -6.260641},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820356000},
#  {'number': 89,
#   'contract_name': 'dublin',
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'address': 'Fitzwilliam Square East',
#   'position': {'lat': 53.335211, 'lng': -6.2509},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1707820359000},
#  {'number': 57,
#   'contract_name': 'dublin',
#   'name': 'GRATTAN STREET',
#   'address': 'Grattan Street',
#   'position': {'lat': 53.339629, 'lng': -6.243778},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 1,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1707820172000},
#  {'number': 80,
#   'contract_name': 'dublin',
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'address': 'St James Hospital (Luas)',
#   'position': {'lat': 53.341359, 'lng': -6.292951},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820642000},
#  {'number': 41,
#   'contract_name': 'dublin',
#   'name': 'HARCOURT TERRACE',
#   'address': 'Harcourt Terrace',
#   'position': {'lat': 53.332763, 'lng': -6.257942},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820118000},
#  {'number': 3,
#   'contract_name': 'dublin',
#   'name': 'BOLTON STREET',
#   'address': 'Bolton Street',
#   'position': {'lat': 53.351182, 'lng': -6.269859},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 12,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1707820146000},
#  {'number': 40,
#   'contract_name': 'dublin',
#   'name': 'JERVIS STREET',
#   'address': 'Jervis Street',
#   'position': {'lat': 53.3483, 'lng': -6.266651},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 21,
#   'available_bike_stands': 8,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1707820338000},
#  {'number': 29,
#   'contract_name': 'dublin',
#   'name': 'ORMOND QUAY UPPER',
#   'address': 'Ormond Quay Upper',
#   'position': {'lat': 53.346057, 'lng': -6.268001},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 11,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1707820404000},
#  {'number': 103,
#   'contract_name': 'dublin',
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'address': 'Grangegorman Lower (South)',
#   'position': {'lat': 53.354663, 'lng': -6.278681},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1707820286000},
#  {'number': 28,
#   'contract_name': 'dublin',
#   'name': 'MOUNTJOY SQUARE WEST',
#   'address': 'Mountjoy Square West',
#   'position': {'lat': 53.356299, 'lng': -6.258586},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 17,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1707820509000},
#  {'number': 39,
#   'contract_name': 'dublin',
#   'name': 'WILTON TERRACE',
#   'address': 'Wilton Terrace',
#   'position': {'lat': 53.332383, 'lng': -6.252717},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1707820609000},
#  {'number': 83,
#   'contract_name': 'dublin',
#   'name': 'EMMET ROAD',
#   'address': 'Emmet Road',
#   'position': {'lat': 53.340714, 'lng': -6.308191},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820306000},
#  {'number': 92,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'address': 'Heuston Bridge (North)',
#   'position': {'lat': 53.347802, 'lng': -6.292432},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1707820284000},
#  {'number': 21,
#   'contract_name': 'dublin',
#   'name': 'LEINSTER STREET SOUTH',
#   'address': 'Leinster Street South',
#   'position': {'lat': 53.34218, 'lng': -6.254485},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 0,
#   'available_bikes': 30,
#   'status': 'OPEN',
#   'last_update': 1707820563000},
#  {'number': 88,
#   'contract_name': 'dublin',
#   'name': 'BLACKHALL PLACE',
#   'address': 'Blackhall Place',
#   'position': {'lat': 53.3488, 'lng': -6.281637},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1707820382000}]

# %%
# Moby API
r = requests.get("https://data.smartdublin.ie/mobybikes-api/last_reading/")
json.loads(r.text)
# Out:
# [{'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 5,
#   'Battery': -12,
#   'BikeIdentifier': '1',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 4,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-12T10:21:13',
#   'LastRentalStart': '2022-07-23T10:20:50',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 1},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 6,
#   'Battery': None,
#   'BikeIdentifier': '2',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:05:11',
#   'LastRentalStart': '2022-07-07T12:40:23',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 2},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 9,
#   'Battery': None,
#   'BikeIdentifier': '5',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-11T13:01:36',
#   'LastRentalStart': '2022-07-11T13:01:18',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 5},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 10,
#   'Battery': None,
#   'BikeIdentifier': '6',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-13T14:49:40',
#   'LastRentalStart': '2022-07-13T14:49:23',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 6},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 12,
#   'Battery': None,
#   'BikeIdentifier': '8',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-13T14:46:58',
#   'LastRentalStart': '2022-07-13T14:46:30',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 8},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 14,
#   'Battery': None,
#   'BikeIdentifier': '11',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:04:49',
#   'LastRentalStart': '2022-07-07T12:40:33',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 11},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 15,
#   'Battery': None,
#   'BikeIdentifier': '13',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-11T15:38:34',
#   'LastRentalStart': '2022-07-11T15:38:16',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 13},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 16,
#   'Battery': -12,
#   'BikeIdentifier': '14',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:26:44',
#   'LastRentalStart': '2022-07-07T12:41:53',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 14},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 19,
#   'Battery': -12,
#   'BikeIdentifier': '17',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-10T14:44:18',
#   'LastRentalStart': '2022-08-01T12:52:50',
#   'Latitude': 53.377,
#   'Longitude': -6.27034,
#   'SpikeID': 17},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 20,
#   'Battery': None,
#   'BikeIdentifier': '18',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-23T22:40:03',
#   'LastRentalStart': '2022-08-21T10:42:06',
#   'Latitude': 53.3769,
#   'Longitude': -6.26987,
#   'SpikeID': 18},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 21,
#   'Battery': None,
#   'BikeIdentifier': '19',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-06-27T16:06:56',
#   'LastRentalStart': '2022-06-27T16:06:42',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 19},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 26,
#   'Battery': None,
#   'BikeIdentifier': '25',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-04T12:09:40',
#   'LastRentalStart': '2022-07-29T12:04:30',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 25},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 27,
#   'Battery': None,
#   'BikeIdentifier': '28',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-06T14:14:52',
#   'LastRentalStart': '2022-07-07T13:19:19',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 28},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 28,
#   'Battery': None,
#   'BikeIdentifier': '29',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2021-05-04T15:18:50',
#   'LastRentalStart': '2022-04-08T15:23:19',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 29},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 31,
#   'Battery': -12,
#   'BikeIdentifier': '21',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-10T14:14:26',
#   'LastRentalStart': '2022-08-02T16:25:38',
#   'Latitude': 53.3769,
#   'Longitude': -6.27036,
#   'SpikeID': 21},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 33,
#   'Battery': None,
#   'BikeIdentifier': '12',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-04T12:09:02',
#   'LastRentalStart': '2022-07-29T08:27:34',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 12},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 38,
#   'Battery': None,
#   'BikeIdentifier': '35',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-09T01:28:31',
#   'LastRentalStart': '2022-07-11T15:25:51',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 35},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 41,
#   'Battery': None,
#   'BikeIdentifier': '38',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:11:32',
#   'LastRentalStart': '2022-07-07T12:41:03',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 38},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 42,
#   'Battery': -12,
#   'BikeIdentifier': '39',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-24T17:57:20',
#   'LastRentalStart': '2022-08-02T17:39:40',
#   'Latitude': 53.3769,
#   'Longitude': -6.26979,
#   'SpikeID': 39},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 43,
#   'Battery': None,
#   'BikeIdentifier': '40',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T12:45:50',
#   'LastRentalStart': '2022-06-25T09:36:27',
#   'Latitude': 53.377,
#   'Longitude': -6.26989,
#   'SpikeID': 40},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 44,
#   'Battery': None,
#   'BikeIdentifier': '41',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 1,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2021-09-21T14:52:41',
#   'LastRentalStart': '2022-05-19T08:39:11',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 41},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 45,
#   'Battery': None,
#   'BikeIdentifier': '42',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-03T08:31:15',
#   'LastRentalStart': '2022-07-03T08:31:39',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 42},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 48,
#   'Battery': -12,
#   'BikeIdentifier': '45',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-17T08:17:48',
#   'LastRentalStart': '2022-07-30T13:44:49',
#   'Latitude': 53.377,
#   'Longitude': -6.26985,
#   'SpikeID': 45},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 49,
#   'Battery': None,
#   'BikeIdentifier': '46',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 1,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-07T03:52:34',
#   'LastRentalStart': '2022-08-02T18:52:37',
#   'Latitude': 53.3725,
#   'Longitude': -6.33764,
#   'SpikeID': 46},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 54,
#   'Battery': -12,
#   'BikeIdentifier': '51',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-23T14:01:12',
#   'LastRentalStart': '2022-08-02T21:58:15',
#   'Latitude': 53.377,
#   'Longitude': -6.26977,
#   'SpikeID': 51},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 55,
#   'Battery': None,
#   'BikeIdentifier': '53',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-06-13T01:02:42',
#   'LastRentalStart': '2022-07-07T13:19:13',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 53},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 58,
#   'Battery': None,
#   'BikeIdentifier': '56',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-13T15:12:56',
#   'LastRentalStart': '2022-07-13T15:03:18',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 56},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 71,
#   'Battery': None,
#   'BikeIdentifier': '68',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:18:13',
#   'LastRentalStart': '2022-07-07T13:18:00',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 68},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 74,
#   'Battery': None,
#   'BikeIdentifier': '71',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 1,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:16:18',
#   'LastRentalStart': '2022-07-07T13:16:06',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 71},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 75,
#   'Battery': -12,
#   'BikeIdentifier': '72',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 5,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-05-30T07:39:42',
#   'LastRentalStart': '2022-05-18T15:38:45',
#   'Latitude': 53.3767,
#   'Longitude': -6.26982,
#   'SpikeID': 72},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 76,
#   'Battery': None,
#   'BikeIdentifier': '73',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 1,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:15:50',
#   'LastRentalStart': '2022-07-07T13:15:36',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 73},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 83,
#   'Battery': 87,
#   'BikeIdentifier': '80',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-06-25T09:14:29',
#   'LastRentalStart': '2022-07-07T12:42:18',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 80},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 88,
#   'Battery': None,
#   'BikeIdentifier': '86',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2021-02-23T16:27:21',
#   'LastRentalStart': '2022-05-12T15:05:22',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 86},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 96,
#   'Battery': None,
#   'BikeIdentifier': '94',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-04-01T14:05:34',
#   'LastRentalStart': '2022-05-16T09:31:18',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 94},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 97,
#   'Battery': None,
#   'BikeIdentifier': '95',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2021-03-12T09:22:58',
#   'LastRentalStart': '2022-04-06T12:56:13',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 95},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 102,
#   'Battery': None,
#   'BikeIdentifier': '100',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T13:13:35',
#   'LastRentalStart': '2022-07-07T13:11:18',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 100},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 104,
#   'Battery': -8,
#   'BikeIdentifier': '104',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-29T05:33:25',
#   'LastRentalStart': '2022-07-30T09:17:09',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 104},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 105,
#   'Battery': None,
#   'BikeIdentifier': '107',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 1,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-11T13:04:15',
#   'LastRentalStart': '2022-07-11T13:03:59',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 107},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 107,
#   'Battery': None,
#   'BikeIdentifier': '112',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2021-05-14T11:19:14',
#   'LastRentalStart': '2022-05-19T09:26:07',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 112},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 108,
#   'Battery': None,
#   'BikeIdentifier': '113',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2021-02-22T09:46:40',
#   'LastRentalStart': '2022-03-31T11:31:58',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 113},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 111,
#   'Battery': -12,
#   'BikeIdentifier': '117',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-23T13:30:15',
#   'LastRentalStart': '2022-08-02T17:13:37',
#   'Latitude': 53.377,
#   'Longitude': -6.26983,
#   'SpikeID': 117},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 112,
#   'Battery': None,
#   'BikeIdentifier': '118',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-11T13:07:09',
#   'LastRentalStart': '2022-07-11T13:06:51',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 118},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 114,
#   'Battery': None,
#   'BikeIdentifier': '110',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-11T15:24:08',
#   'LastRentalStart': '2022-07-11T15:14:46',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 110},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 117,
#   'Battery': -12,
#   'BikeIdentifier': '105',
#   'BikeTypeName': 'Workshop',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-26T07:44:46',
#   'LastRentalStart': '2022-08-02T20:42:20',
#   'Latitude': 53.377,
#   'Longitude': -6.2697,
#   'SpikeID': 105},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 118,
#   'Battery': None,
#   'BikeIdentifier': '32',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-07T12:44:15',
#   'LastRentalStart': '2022-06-25T09:37:08',
#   'Latitude': 53.377,
#   'Longitude': -6.2699,
#   'SpikeID': 32},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 119,
#   'Battery': None,
#   'BikeIdentifier': '84',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-07-28T15:46:01',
#   'LastRentalStart': '2022-07-07T12:39:15',
#   'Latitude': 53.377,
#   'Longitude': -6.26975,
#   'SpikeID': 84},
#  {'HarvestTime': '2023-01-11T15:50:02',
#   'BikeID': 121,
#   'Battery': None,
#   'BikeIdentifier': '103',
#   'BikeTypeName': 'DUB-General',
#   'EBikeProfileID': 1,
#   'EBikeStateID': 2,
#   'IsEBike': True,
#   'IsMotor': True,
#   'IsSmartLock': False,
#   'LastGPSTime': '2022-08-04T12:09:50',
#   'LastRentalStart': '2022-07-29T12:17:53',
#   'Latitude': 0.0,
#   'Longitude': 0.0,
#   'SpikeID': 103}]

# %%
# Bleeper
r = requests.get("https://data.smartdublin.ie/bleeperbike-api/last_snapshot/")
json.loads(r.text)
# Out:
# [{'id': 66797809,
#   'bike_id': '0099b5ac-4975-4d24-8731-96eadfc6c2b1',
#   'name': 2449,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3722,
#   'lon': -6.38919,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:19:21',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797405,
#   'bike_id': '0117a031-ba2a-4230-a9a0-6dabafd2e8bf',
#   'name': 2689,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3448,
#   'lon': -6.27633,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.53,
#   'last_reported': '1970-01-20T18:23:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797637,
#   'bike_id': '011b55a9-29bf-4ffd-b496-1164368337ac',
#   'name': 2549,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3634,
#   'lon': -6.31155,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797714,
#   'bike_id': '0146fb2c-8598-4878-9505-e27d20980f15',
#   'name': 1369,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2875,
#   'lon': -6.11578,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.63,
#   'last_reported': '1970-01-20T18:21:10',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797787,
#   'bike_id': '017bc803-49ac-4d44-97a7-041c999879d6',
#   'name': 2568,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3114,
#   'lon': -6.23614,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:22:12',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797439,
#   'bike_id': '01fef127-8265-41a2-ba0c-a9f698ee2a8f',
#   'name': 2215,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3828,
#   'lon': -6.16002,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:05:49',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797879,
#   'bike_id': '0278b6bd-1ff5-4e49-af5d-bcc40e8d662e',
#   'name': 2254,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3889,
#   'lon': -6.07343,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:21:02',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797764,
#   'bike_id': '027d2399-557f-44d5-975e-dede329246ac',
#   'name': 1059,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3718,
#   'lon': -6.37676,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.2,
#   'last_reported': '1970-01-20T18:20:19',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797698,
#   'bike_id': '03104b83-cd1a-4db2-9cdc-30a2de513726',
#   'name': 2245,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3769,
#   'lon': -6.2237,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:22:48',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797559,
#   'bike_id': '040baae5-aee6-42f6-9baf-2b1996781c9f',
#   'name': 2079,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4935,
#   'lon': -6.10895,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.98,
#   'last_reported': '1970-01-20T18:12:06',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797864,
#   'bike_id': '060d1558-918e-4bba-8453-e57664725a67',
#   'name': 1178,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.371,
#   'lon': -6.23846,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:22:52',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797561,
#   'bike_id': '060e2b36-4b60-402d-a355-5a5921e0fb97',
#   'name': 2704,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3334,
#   'lon': -6.24355,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.1,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797436,
#   'bike_id': '069040c4-6c0e-4d6e-8b97-299ffa1edaca',
#   'name': 2209,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.328,
#   'lon': -6.2208,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:20:56',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797647,
#   'bike_id': '077076b5-5174-4b38-b313-8ff982138bd4',
#   'name': 2586,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3289,
#   'lon': -6.22892,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797542,
#   'bike_id': '077ae760-e6a8-47b7-9fd2-6adfe0cf7594',
#   'name': 1269,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2948,
#   'lon': -6.13452,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:19:53',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797624,
#   'bike_id': '096f448b-c301-42e2-b36b-154e3997b3d2',
#   'name': 2728,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.336,
#   'lon': -6.26231,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797448,
#   'bike_id': '097aed57-ac51-4549-816c-c30e884a327c',
#   'name': 2288,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3733,
#   'lon': -6.28494,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.14,
#   'last_reported': '1970-01-20T18:15:06',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797829,
#   'bike_id': '09ef9e37-9d69-4bf0-8bcb-a01b3126420f',
#   'name': 1142,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3572,
#   'lon': -6.22519,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797430,
#   'bike_id': '0b432f14-f997-4fc4-8d23-91ca31c94044',
#   'name': 1352,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.523,
#   'lon': -6.10168,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T17:23:02',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797645,
#   'bike_id': '0beb1c12-50d4-4644-9b66-992192180f91',
#   'name': 1072,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.328,
#   'lon': -6.22102,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.89,
#   'last_reported': '1970-01-20T18:22:41',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797860,
#   'bike_id': '0c222eac-fecf-4819-9500-58dda0e6632c',
#   'name': 2468,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3315,
#   'lon': -6.21551,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:21:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797538,
#   'bike_id': '0c6c88d6-448f-4f16-a16b-f42c3e6002df',
#   'name': 1389,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3305,
#   'lon': -6.23177,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797457,
#   'bike_id': '0c6e2a76-01aa-46c6-bd0e-14600bb57513',
#   'name': 2696,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3824,
#   'lon': -6.1508,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:10:14',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797478,
#   'bike_id': '0d3691e0-cd0e-42d6-bebb-be1567836585',
#   'name': 2762,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3204,
#   'lon': -6.31577,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.79,
#   'last_reported': '1970-01-20T18:22:05',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797836,
#   'bike_id': '0d48f9c6-d9f9-445e-93c8-feeb9d977f36',
#   'name': 1233,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.342,
#   'lon': -6.22787,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:22:45',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797723,
#   'bike_id': '0d59f408-51ce-4039-86d7-628c3a6773cf',
#   'name': 2202,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5706,
#   'lon': -6.10071,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797676,
#   'bike_id': '0e67913b-8610-474b-ad15-525fccf50e19',
#   'name': 2487,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4546,
#   'lon': -6.24328,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.82,
#   'last_reported': '1970-01-20T18:10:54',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797543,
#   'bike_id': '0f538c76-91f2-4d3b-a368-4764f7743b37',
#   'name': 2416,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6085,
#   'lon': -6.18274,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:18:00',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797865,
#   'bike_id': '0f76d6f0-32af-49cc-91b5-b44e52e34700',
#   'name': 2753,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5186,
#   'lon': -6.09167,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T17:19:12',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797794,
#   'bike_id': '0fc606c1-b7eb-4b60-b318-68d2b461f0c4',
#   'name': 2253,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6043,
#   'lon': -6.18457,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:39',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797608,
#   'bike_id': '103313e2-b55c-4595-92dd-9cd07773ab34',
#   'name': 2132,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2964,
#   'lon': -6.18093,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:06:20',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797720,
#   'bike_id': '1066f7d7-8b99-4845-a132-ddac40f569aa',
#   'name': 2552,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3433,
#   'lon': -6.24974,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T17:53:49',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797727,
#   'bike_id': '10e0d5b6-ba86-4182-b606-d9fabcf62c35',
#   'name': 2580,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5229,
#   'lon': -6.08191,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T17:54:40',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797685,
#   'bike_id': '11380e65-89d7-49fe-bf00-48baab2f1b72',
#   'name': 1208,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5745,
#   'lon': -6.11932,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:17:51',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797527,
#   'bike_id': '1180946d-512e-4f4f-a589-0e81728787e7',
#   'name': 2544,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.345,
#   'lon': -6.23606,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797414,
#   'bike_id': '122855bc-ed36-48e4-9dbd-26417bbc93e5',
#   'name': 2211,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.344,
#   'lon': -6.27772,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.53,
#   'last_reported': '1970-01-20T18:16:24',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797582,
#   'bike_id': '12aeb321-c371-4b8c-a134-e5b7257feb18',
#   'name': 2080,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3444,
#   'lon': -6.27511,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.5,
#   'last_reported': '1970-01-20T18:18:04',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797534,
#   'bike_id': '13455802-26bf-4e6d-b2a6-7f799b78c186',
#   'name': 1129,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3456,
#   'lon': -6.27007,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.87,
#   'last_reported': '1970-01-20T18:21:10',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797427,
#   'bike_id': '13ebd07d-b73d-4561-a788-70055e0775a6',
#   'name': 1267,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3449,
#   'lon': -6.23164,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:31',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797592,
#   'bike_id': '13f14d82-5f84-4449-b84f-690f9d3ed6a8',
#   'name': 1270,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3456,
#   'lon': -6.2354,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.79,
#   'last_reported': '1970-01-20T18:23:38',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797500,
#   'bike_id': '143501e2-a37f-453e-8d17-84c17c2a607e',
#   'name': 2757,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.374,
#   'lon': -6.26303,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:09:53',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797831,
#   'bike_id': '14d99152-d9f0-48e6-b0b2-ee4db4c70c42',
#   'name': 1273,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3401,
#   'lon': -6.22391,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:21:21',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797748,
#   'bike_id': '150abbdb-8a66-49cc-8174-68ce1e13857a',
#   'name': 1237,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3588,
#   'lon': -6.25732,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:23:38',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797875,
#   'bike_id': '16626fad-ad91-459e-9c3a-83542fb58501',
#   'name': 1117,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3888,
#   'lon': -6.07334,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:14:25',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797709,
#   'bike_id': '177a6dfe-5b83-461c-90c7-d7ac39ec1ec4',
#   'name': 2147,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3759,
#   'lon': -6.40072,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.68,
#   'last_reported': '1970-01-20T18:22:08',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797690,
#   'bike_id': '17c37312-48ed-4aca-a1cb-2d46d1906079',
#   'name': 2093,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6119,
#   'lon': -6.1827,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.98,
#   'last_reported': '1970-01-20T16:42:50',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797880,
#   'bike_id': '185546db-fb89-4645-8868-28c23cc148a7',
#   'name': 2143,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3336,
#   'lon': -6.25835,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797648,
#   'bike_id': '199b788e-17ed-4543-8471-fa8ad417bd85',
#   'name': 2363,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5744,
#   'lon': -6.11937,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:17:51',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797795,
#   'bike_id': '1a0e029b-9025-49e3-abe3-668080f3230a',
#   'name': 2036,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4535,
#   'lon': -6.21959,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:11:09',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797631,
#   'bike_id': '1a4ff422-3eda-4257-a664-104a467bf1b4',
#   'name': 1242,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3471,
#   'lon': -6.23278,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797701,
#   'bike_id': '1bbd3fde-c5e2-4988-8638-894ccb0a2def',
#   'name': 1390,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4657,
#   'lon': -6.21901,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:12:21',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797842,
#   'bike_id': '1bc3bd1e-1eb6-420c-940d-6db91d1d0277',
#   'name': 2251,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3116,
#   'lon': -6.23304,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:23:33',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797833,
#   'bike_id': '1bf88e66-8434-47b9-9576-95c073e3de30',
#   'name': 2104,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3376,
#   'lon': -6.252,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797824,
#   'bike_id': '1c073355-1e63-4a48-b310-5241ea230898',
#   'name': 1388,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3255,
#   'lon': -6.22668,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:15:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797450,
#   'bike_id': '1c4a1696-a693-40ba-9d2e-74bda7f977b6',
#   'name': 2445,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.487,
#   'lon': -6.14842,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:05:45',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797486,
#   'bike_id': '1cf32937-7ade-43a7-80f0-17e705bfbaf9',
#   'name': 2453,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2947,
#   'lon': -6.18474,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.67,
#   'last_reported': '1970-01-20T18:13:26',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797695,
#   'bike_id': '1d8d12ad-f4b8-475d-8607-e8c3ddfd5c2f',
#   'name': 2723,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3889,
#   'lon': -6.07292,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:09:15',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797564,
#   'bike_id': '1dbbf9e9-3cf4-4371-9be7-7154f8e97cc9',
#   'name': 1373,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3396,
#   'lon': -6.23003,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:23:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797688,
#   'bike_id': '1de0eafc-5e5e-424e-a0d4-489365d2d9b3',
#   'name': 2434,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3375,
#   'lon': -6.25139,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.73,
#   'last_reported': '1970-01-20T18:23:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797877,
#   'bike_id': '1f7272a5-53f9-49db-9699-05eb4a928857',
#   'name': 1374,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4434,
#   'lon': -6.12541,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.98,
#   'last_reported': '1970-01-20T17:49:11',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797526,
#   'bike_id': '1fa9bcd2-6f98-4635-a7cd-81de3d7d4e1b',
#   'name': 2497,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3045,
#   'lon': -6.28315,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:15:17',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797674,
#   'bike_id': '2101dcd4-80f5-4b87-bdc6-aa58b216ff25',
#   'name': 2761,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4784,
#   'lon': -6.11536,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T17:58:12',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797585,
#   'bike_id': '2119980b-9fae-450c-86b9-c232904f4ee3',
#   'name': 2195,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3461,
#   'lon': -6.27585,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:22:46',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797772,
#   'bike_id': '2202c075-e9ad-4f43-84d3-ae78bb68639e',
#   'name': 2194,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3405,
#   'lon': -6.30758,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:22:46',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797755,
#   'bike_id': '22712f41-0e70-4ece-a868-37d944c08ef0',
#   'name': 2058,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6088,
#   'lon': -6.18239,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.81,
#   'last_reported': '1970-01-20T18:18:00',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797489,
#   'bike_id': '22e1159f-d5ad-47da-8c5d-348e4fb9a2a3',
#   'name': 2570,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5223,
#   'lon': -6.09558,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.97,
#   'last_reported': '1970-01-20T18:12:27',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797807,
#   'bike_id': '234e3450-871d-4801-a584-e04babd787ed',
#   'name': 1071,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6043,
#   'lon': -6.18452,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T17:53:23',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797574,
#   'bike_id': '240e8895-dc5d-4a1e-95f8-09718579da42',
#   'name': 2268,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6119,
#   'lon': -6.18272,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.97,
#   'last_reported': '1970-01-20T17:53:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797620,
#   'bike_id': '2559704a-2787-41e5-9964-8128a4f81f5a',
#   'name': 2171,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3431,
#   'lon': -6.24094,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.98,
#   'last_reported': '1970-01-20T18:23:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797627,
#   'bike_id': '2572ee48-2302-4c4e-94c7-69d84ce71fbd',
#   'name': 1203,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3364,
#   'lon': -6.24785,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797435,
#   'bike_id': '257d98f4-60ec-4b56-9daf-7fc924e4a225',
#   'name': 2798,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3396,
#   'lon': -6.26062,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.44,
#   'last_reported': '1970-01-20T18:23:38',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797612,
#   'bike_id': '26405180-1470-4faa-b47d-08a711ca1015',
#   'name': 2766,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3632,
#   'lon': -6.21926,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.87,
#   'last_reported': '1970-01-20T18:23:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797632,
#   'bike_id': '26f07aee-3589-4600-8276-4b591dc69c6a',
#   'name': 2699,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3396,
#   'lon': -6.25145,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797683,
#   'bike_id': '27784069-1d02-4ba0-b939-d03ea5bec7fd',
#   'name': 2430,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3455,
#   'lon': -6.23385,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797600,
#   'bike_id': '286e40e3-30d9-462b-a5f0-b6be49a4e3f3',
#   'name': 1056,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3521,
#   'lon': -6.26033,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.16,
#   'last_reported': '1970-01-20T18:22:50',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797540,
#   'bike_id': '28715f45-3678-423a-8269-0c808df6a4b0',
#   'name': 1041,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.313,
#   'lon': -6.23849,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:21:18',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797459,
#   'bike_id': '288b5b2a-b358-44b9-890e-0c777ffebcff',
#   'name': 1349,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3321,
#   'lon': -6.21519,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.98,
#   'last_reported': '1970-01-20T18:22:14',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797693,
#   'bike_id': '28a72d9b-92fa-4772-b9f7-b030528f25e1',
#   'name': 2472,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3401,
#   'lon': -6.22362,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.65,
#   'last_reported': '1970-01-20T18:22:41',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797409,
#   'bike_id': '28de0a87-fc2b-49b9-aa54-93a9bd56d658',
#   'name': 2213,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3365,
#   'lon': -6.26562,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797572,
#   'bike_id': '29a55afa-6bf0-4a01-aecb-7e81f0f3fceb',
#   'name': 2021,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4858,
#   'lon': -6.15093,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:22:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797510,
#   'bike_id': '2aa20f23-574b-4fdc-8d1f-86d570d9789c',
#   'name': 1364,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5706,
#   'lon': -6.10073,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:36',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797487,
#   'bike_id': '2c526323-75a3-4c72-8b97-9fecf2e204f8',
#   'name': 2408,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6082,
#   'lon': -6.18245,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.87,
#   'last_reported': '1970-01-20T18:18:04',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797680,
#   'bike_id': '2c8aa4c4-68bc-41e6-bbc9-30db4d994c2a',
#   'name': 1177,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3443,
#   'lon': -6.27601,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.97,
#   'last_reported': '1970-01-20T18:13:54',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797656,
#   'bike_id': '2ce58d69-f0df-4dc7-8c00-4c6f9afb0003',
#   'name': 2534,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3335,
#   'lon': -6.27254,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:22:24',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797536,
#   'bike_id': '2d3a5231-781e-44aa-aae4-29151db360fb',
#   'name': 2584,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5985,
#   'lon': -6.16171,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:13:26',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797539,
#   'bike_id': '2d5d3dee-d334-4dec-bb8d-d70ec202516a',
#   'name': 2688,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3637,
#   'lon': -6.31125,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.73,
#   'last_reported': '1970-01-20T18:22:08',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797466,
#   'bike_id': '2dd0c425-70e4-42aa-9549-3b68fdb71947',
#   'name': 2260,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3253,
#   'lon': -6.24086,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797757,
#   'bike_id': '2e05836b-34a4-4196-9ed6-9613f33f3903',
#   'name': 1074,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2982,
#   'lon': -6.16565,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:20',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797718,
#   'bike_id': '2e2d8e57-15bd-410a-a3f8-dd7c2d32ee87',
#   'name': 2378,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3342,
#   'lon': -6.26146,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.63,
#   'last_reported': '1970-01-20T18:23:32',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797743,
#   'bike_id': '2e793aa7-c5f4-4cb5-85fb-0e00f2114183',
#   'name': 1249,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3477,
#   'lon': -6.30708,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:21:17',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797546,
#   'bike_id': '2e95039c-d359-4e51-b164-a72e704f406d',
#   'name': 2249,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3887,
#   'lon': -6.07026,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:14:25',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797581,
#   'bike_id': '2f16f996-2d12-47a3-be56-7bf06160106a',
#   'name': 2162,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3467,
#   'lon': -6.27273,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.14,
#   'last_reported': '1970-01-20T18:23:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797499,
#   'bike_id': '31b186bf-2ff4-4a04-8478-aa64e08c52b7',
#   'name': 1098,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3457,
#   'lon': -6.27018,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:20:51',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797665,
#   'bike_id': '3265e6b6-1da2-464e-b611-cc30eb87828f',
#   'name': 1169,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3657,
#   'lon': -6.34584,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:21:08',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797659,
#   'bike_id': '32dc998a-3e20-4737-8552-fa42ec8cf138',
#   'name': 1091,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3172,
#   'lon': -6.21491,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:24',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797474,
#   'bike_id': '3300d17d-fe74-4677-97f0-1b0883606f17',
#   'name': 1173,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3266,
#   'lon': -6.29035,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:21:54',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797593,
#   'bike_id': '34b8d86e-9ee2-4eda-b557-7b101f69ea27',
#   'name': 2592,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4633,
#   'lon': -6.21811,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:20:19',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797784,
#   'bike_id': '359c6210-b9c7-48d9-b35b-459862ea1e76',
#   'name': 2486,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3378,
#   'lon': -6.26561,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797445,
#   'bike_id': '361553d0-00f4-4bd3-a456-b2738cf4ad17',
#   'name': 2276,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3347,
#   'lon': -6.21382,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:20:38',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797410,
#   'bike_id': '365b43f4-1f28-48ce-aff9-90184e397488',
#   'name': 2214,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3313,
#   'lon': -6.23458,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:36',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797705,
#   'bike_id': '3671cadb-d632-4d1b-8b99-bbdd1dbd0d12',
#   'name': 2392,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3456,
#   'lon': -6.27634,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797769,
#   'bike_id': '36a6e996-f4f5-466c-a805-10389cdf83b1',
#   'name': 2175,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3809,
#   'lon': -6.16511,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:21:17',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797485,
#   'bike_id': '36d03c9f-2b91-4caf-b81b-4757aeccf04e',
#   'name': 2086,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3497,
#   'lon': -6.26722,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.3,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797565,
#   'bike_id': '3749ce9c-4648-45b9-8672-7de8d6beb9db',
#   'name': 2120,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3257,
#   'lon': -6.22677,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.73,
#   'last_reported': '1970-01-20T18:20:36',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797551,
#   'bike_id': '3786dac2-b827-43c4-828d-906e86fecc26',
#   'name': 2740,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3507,
#   'lon': -6.25462,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.71,
#   'last_reported': '1970-01-20T18:23:15',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797502,
#   'bike_id': '384f6b98-2125-48e8-a80b-873bc779bd74',
#   'name': 2510,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3283,
#   'lon': -6.20869,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:20:58',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797554,
#   'bike_id': '38decabf-d09c-40b4-a5ca-feb863a3bcfa',
#   'name': 2452,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3447,
#   'lon': -6.27623,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:16:33',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797760,
#   'bike_id': '38ec31a8-b81c-4b3c-95d2-05e276dcfc06',
#   'name': 2283,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6059,
#   'lon': -6.17943,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.8,
#   'last_reported': '1970-01-20T17:38:13',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797625,
#   'bike_id': '39c9497d-44d4-4955-b1c2-217c588f58af',
#   'name': 2076,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2885,
#   'lon': -6.1141,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:11:53',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797749,
#   'bike_id': '3a1d0958-985a-47fd-b371-773e1716b09a',
#   'name': 2248,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4934,
#   'lon': -6.10906,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.99,
#   'last_reported': '1970-01-20T18:03:57',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797555,
#   'bike_id': '3a99c4c1-608e-4d46-88e8-f0d02e4f0bdb',
#   'name': 1211,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3202,
#   'lon': -6.26476,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:23:38',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797521,
#   'bike_id': '3b059221-d630-44cc-b4b4-f36aa36ce4db',
#   'name': 2047,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2945,
#   'lon': -6.13385,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:19:36',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797706,
#   'bike_id': '3b62f909-8047-4df9-9794-d20a43ffb516',
#   'name': 2329,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3267,
#   'lon': -6.29051,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:19:50',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797775,
#   'bike_id': '3ba7d3f0-a739-4eac-b7f1-f207d75410ad',
#   'name': 1017,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.455,
#   'lon': -6.18122,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:04:57',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797653,
#   'bike_id': '3c4df93e-0d76-4f04-b1af-0a466a2aa795',
#   'name': 1007,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3419,
#   'lon': -6.22621,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:22:07',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797682,
#   'bike_id': '3c59cf35-b44a-4ee0-8a54-627868d69ce1',
#   'name': 2687,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3053,
#   'lon': -6.21988,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.89,
#   'last_reported': '1970-01-20T18:23:27',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797628,
#   'bike_id': '3c696c38-53d0-41eb-8c73-22a3a04785ec',
#   'name': 2403,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3887,
#   'lon': -6.07443,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:21:00',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797799,
#   'bike_id': '3d1fbd4e-4438-43cb-9449-82e3f2fe38ff',
#   'name': 2158,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3046,
#   'lon': -6.28305,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.68,
#   'last_reported': '1970-01-20T18:21:09',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797810,
#   'bike_id': '3d5acdd2-ee68-445c-ab2c-838095309eed',
#   'name': 2594,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3798,
#   'lon': -6.17424,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:19:00',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797776,
#   'bike_id': '3da56916-6f6d-4795-8630-4b1d0fdbfdda',
#   'name': 1020,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3496,
#   'lon': -6.22998,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:22:46',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797655,
#   'bike_id': '3db8a577-4b76-4ad5-9a6b-0f766aeaa459',
#   'name': 2467,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3286,
#   'lon': -6.22852,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.3,
#   'last_reported': '1970-01-20T18:23:33',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797552,
#   'bike_id': '3eee9980-1d13-4eb7-b437-4508a64d03ea',
#   'name': 1386,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.309,
#   'lon': -6.22163,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.97,
#   'last_reported': '1970-01-20T18:21:09',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797691,
#   'bike_id': '3f016be1-6ddb-420e-b0ba-65a67474aeed',
#   'name': 2010,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3186,
#   'lon': -6.21383,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.48,
#   'last_reported': '1970-01-20T18:22:52',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797408,
#   'bike_id': '3f238ec4-931f-4b8d-846f-334da5248e2c',
#   'name': 2210,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.38,
#   'lon': -6.28841,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:22:26',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797629,
#   'bike_id': '3fd099e6-1624-4f92-878d-31cd1adfe456',
#   'name': 2743,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3356,
#   'lon': -6.26891,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:23:34',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797830,
#   'bike_id': '3fec0126-e5ea-43b7-8671-0a4173e6ae8e',
#   'name': 1197,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3478,
#   'lon': -6.27507,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.65,
#   'last_reported': '1970-01-20T18:23:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797667,
#   'bike_id': '40a790e0-46f1-4cfc-b743-d1bcba8ac3c4',
#   'name': 1047,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3795,
#   'lon': -6.28798,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:15:58',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797580,
#   'bike_id': '40fe04fa-55d4-4bf9-bc0b-46d699bfbffe',
#   'name': 1148,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3584,
#   'lon': -6.22808,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.4,
#   'last_reported': '1970-01-20T18:03:44',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797607,
#   'bike_id': '41aa9ad5-2568-42fd-97a2-97ed86cb4402',
#   'name': 2019,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4861,
#   'lon': -6.14882,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:18:28',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797719,
#   'bike_id': '42e179f0-e6e9-49a8-9433-af11c32be088',
#   'name': 2735,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4523,
#   'lon': -6.15321,
# ...
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797661,
#   'bike_id': 'ea98d59d-788d-42a9-84fb-139b052e7cc3',
#   'name': 2693,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2981,
#   'lon': -6.1604,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:20:47',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797406,
#   'bike_id': 'eace435a-29bd-48ee-a555-fc9a800b280b',
#   'name': 1175,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2904,
#   'lon': -6.12654,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.44,
#   'last_reported': '1970-01-20T18:19:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797696,
#   'bike_id': 'eb2fc59b-997e-4d71-a4da-b9a95845f941',
#   'name': 2103,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5346,
#   'lon': -6.09491,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T15:13:43',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797816,
#   'bike_id': 'eb61fa5e-9f7e-49e2-a8dc-1d2a1e21423d',
#   'name': 2543,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.6102,
#   'lon': -6.18237,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.98,
#   'last_reported': '1970-01-20T17:53:25',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797531,
#   'bike_id': 'ee11c112-a994-4c68-8b85-590d0de65565',
#   'name': 2316,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3003,
#   'lon': -6.17532,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:22:48',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797477,
#   'bike_id': 'ef630e02-d3e4-40b2-beee-761ae1f80bcc',
#   'name': 2458,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3448,
#   'lon': -6.23148,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797852,
#   'bike_id': 'efafc684-8c12-4904-b882-2b29aa0779fb',
#   'name': 2324,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2931,
#   'lon': -6.13172,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.5,
#   'last_reported': '1970-01-20T18:08:22',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797664,
#   'bike_id': 'efd49edf-6ccd-4364-bcd9-d20949d075a6',
#   'name': 1192,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3823,
#   'lon': -6.15089,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.7,
#   'last_reported': '1970-01-20T18:21:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797708,
#   'bike_id': 'f0779370-bd37-4cc7-b152-0cad93bb6a6f',
#   'name': 2166,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.301,
#   'lon': -6.177,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:20:23',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797441,
#   'bike_id': 'f0dec9ed-edf6-4899-9a5d-07851139a253',
#   'name': 2513,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3873,
#   'lon': -6.29752,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.97,
#   'last_reported': '1970-01-20T18:22:16',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797426,
#   'bike_id': 'f1643376-2dea-47ba-9fbd-9d12658295a5',
#   'name': 1343,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2902,
#   'lon': -6.13124,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.94,
#   'last_reported': '1970-01-20T18:10:09',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797840,
#   'bike_id': 'f17369c3-03f4-417a-a6d8-c553da498287',
#   'name': 2099,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3376,
#   'lon': -6.22557,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.87,
#   'last_reported': '1970-01-20T18:20:45',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797418,
#   'bike_id': 'f17db50d-f882-47a7-b6d3-227bf4faf326',
#   'name': 2261,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3444,
#   'lon': -6.27568,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:14:54',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797707,
#   'bike_id': 'f1c90762-d7be-457f-ba1d-225162f588d8',
#   'name': 1028,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.5744,
#   'lon': -6.1194,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:03:24',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797662,
#   'bike_id': 'f272c1a1-c814-4fb2-a2ba-c304991abc75',
#   'name': 2275,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3722,
#   'lon': -6.38912,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:15:26',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797420,
#   'bike_id': 'f2c2e93c-e05c-4059-aebe-cd154babce45',
#   'name': 2800,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3761,
#   'lon': -6.40075,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:19:24',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797468,
#   'bike_id': 'f2f34618-6431-4587-98f1-978773908619',
#   'name': 2440,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3583,
#   'lon': -6.22765,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.8,
#   'last_reported': '1970-01-20T18:15:47',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797654,
#   'bike_id': 'f32681bd-7d06-40f4-89a7-4d0f84375cf6',
#   'name': 2159,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.358,
#   'lon': -6.22763,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.09,
#   'last_reported': '1970-01-20T18:20:28',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797884,
#   'bike_id': 'f334351f-e2e1-4ff7-b7e4-2eab036d4452',
#   'name': 2517,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3157,
#   'lon': -6.23479,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:21:18',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797790,
#   'bike_id': 'f3a38785-3f2c-4f1a-a83b-41f8234b7fbd',
#   'name': 2300,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2978,
#   'lon': -6.16001,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.27,
#   'last_reported': '1970-01-20T18:09:29',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797785,
#   'bike_id': 'f3aa942f-91a9-480a-81e3-7cc5d9d0867d',
#   'name': 2252,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3258,
#   'lon': -6.28992,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.83,
#   'last_reported': '1970-01-20T18:23:36',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797733,
#   'bike_id': 'f432ab3e-dc45-4d6a-924c-7dc13cb33fba',
#   'name': 2299,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3894,
#   'lon': -6.10986,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:22:40',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797736,
#   'bike_id': 'f4517f7e-4aed-48bb-a9d7-50bf20897599',
#   'name': 2012,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3707,
#   'lon': -6.20705,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:22:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797530,
#   'bike_id': 'f454eb9c-0387-4801-907c-2f991fbe6be0',
#   'name': 2764,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3447,
#   'lon': -6.27616,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:13:54',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797583,
#   'bike_id': 'f4ea3c54-2416-45d8-afcb-81c31092fd3a',
#   'name': 2075,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3886,
#   'lon': -6.07334,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:20:58',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797871,
#   'bike_id': 'f544de4f-5922-4e8f-86e7-4dc7a912ed2c',
#   'name': 2250,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3132,
#   'lon': -6.20716,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797523,
#   'bike_id': 'f5510dae-b975-42c1-861a-f615a0ab1745',
#   'name': 2186,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.357,
#   'lon': -6.22484,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:23:32',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797818,
#   'bike_id': 'f5bc6bab-1de1-469b-a749-20dd395b6a09',
#   'name': 2343,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3673,
#   'lon': -6.17317,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.68,
#   'last_reported': '1970-01-20T18:22:43',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797519,
#   'bike_id': 'f60225e2-4c5d-4999-babe-6aa2b6e8dac4',
#   'name': 2555,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.38,
#   'lon': -6.1746,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:16:02',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797789,
#   'bike_id': 'f6479cb1-170d-490c-8ed9-8f44063235e5',
#   'name': 2165,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3646,
#   'lon': -6.18424,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:13:03',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797562,
#   'bike_id': 'f6eee4b2-8a31-42cd-b86f-e64081947616',
#   'name': 1227,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3591,
#   'lon': -6.19617,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T18:21:39',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797545,
#   'bike_id': 'f7ccbadd-f28e-47f1-9ca9-3e5a105ff9ec',
#   'name': 2273,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.2964,
#   'lon': -6.18592,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:18:04',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797569,
#   'bike_id': 'f7f150fb-7dfc-4035-8f78-4dadad621984',
#   'name': 2393,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3448,
#   'lon': -6.27626,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:16:32',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797694,
#   'bike_id': 'f80d1208-762f-4401-859f-87cbe7b6ba98',
#   'name': 2787,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4633,
#   'lon': -6.21812,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.96,
#   'last_reported': '1970-01-20T17:42:23',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797681,
#   'bike_id': 'f9746902-3d81-4cda-8f5e-c28f29638b4b',
#   'name': 2546,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3443,
#   'lon': -6.28239,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:22:04',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797475,
#   'bike_id': 'f99cd9fc-5fcd-4e09-bf16-c1cd75cfbb08',
#   'name': 2139,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3799,
#   'lon': -6.17462,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.7,
#   'last_reported': '1970-01-20T18:21:16',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797425,
#   'bike_id': 'f9bca2c5-0f51-4b1b-8785-8c607c6e8253',
#   'name': 2286,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3442,
#   'lon': -6.27739,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.9,
#   'last_reported': '1970-01-20T18:16:25',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797679,
#   'bike_id': 'faabfeb6-0e77-4682-b98c-92f555f4eb40',
#   'name': 2174,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3763,
#   'lon': -6.1782,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.65,
#   'last_reported': '1970-01-20T18:21:30',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797557,
#   'bike_id': 'fc9ce516-6d5e-4d0f-996e-9cc7caa28494',
#   'name': 2266,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3805,
#   'lon': -6.17226,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.93,
#   'last_reported': '1970-01-20T18:16:40',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797589,
#   'bike_id': 'fd54e052-4749-4cba-ae1f-a0d53d379677',
#   'name': 1026,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3866,
#   'lon': -6.14687,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.95,
#   'last_reported': '1970-01-20T18:11:40',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797827,
#   'bike_id': 'fec4d6c8-77e3-489b-b360-7e8a08f6641d',
#   'name': 2547,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.4859,
#   'lon': -6.15089,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.92,
#   'last_reported': '1970-01-20T18:19:37',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797570,
#   'bike_id': 'fed6aa8d-7725-4024-b1b4-961d79100753',
#   'name': 2725,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3404,
#   'lon': -6.23631,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.23,
#   'last_reported': '1970-01-20T18:23:35',
#   'harvest_time': '2024-02-13T10:35:03'},
#  {'id': 66797802,
#   'bike_id': 'fed967b5-4728-4693-ad32-159a49fa7e39',
#   'name': 2519,
#   'is_reserved': False,
#   'is_disabled': False,
#   'lat': 53.3887,
#   'lon': -6.0745,
#   'vehicle_type_id': '79ab8c6d-5498-4ec7-8fdc-efbfedc055ed',
#   'station_id': None,
#   'current_fuel_percent': 0.91,
#   'last_reported': '1970-01-20T18:22:40',
#   'harvest_time': '2024-02-13T10:35:03'}]

# %%
#Weather 
w = requests.get(WEATHER_URI, params={"lat": 53.344, "lon": -6.2672, "appid": WEATHER_API_KEY})
json.loads(w.text)
# Out:
# {'coord': {'lon': -6.2672, 'lat': 53.344},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 281.07,
#   'feels_like': 279.46,
#   'temp_min': 280.3,
#   'temp_max': 281.69,
#   'pressure': 1005,
#   'humidity': 85},
#  'visibility': 10000,
#  'wind': {'speed': 2.57, 'deg': 170},
#  'clouds': {'all': 75},
#  'dt': 1707820501,
#  'sys': {'type': 2,
#   'id': 2016139,
#   'country': 'IE',
#   'sunrise': 1707810533,
#   'sunset': 1707845394},
#  'timezone': 0,
#  'id': 2964574,
#  'name': 'Dublin',
#  'cod': 200}
